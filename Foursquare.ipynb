# %% [markdown]
# ## Foursquare

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in c:\mypython\anaconda3\envs\py36\lib\site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\mypython\anaconda3\envs\py36\lib\site-packages (from geopy) (1.50)
# Requirement already satisfied: folium==0.5.0 in c:\mypython\anaconda3\envs\py36\lib\site-packages (0.5.0)
# Requirement already satisfied: branca in c:\mypython\anaconda3\envs\py36\lib\site-packages (from folium==0.5.0) (0.4.1)
# Requirement already satisfied: jinja2 in c:\mypython\anaconda3\envs\py36\lib\site-packages (from folium==0.5.0) (2.10)
# Requirement already satisfied: requests in c:\mypython\anaconda3\envs\py36\lib\site-packages (from folium==0.5.0) (2.18.4)
# Requirement already satisfied: six in c:\mypython\anaconda3\envs\py36\lib\site-packages (from folium==0.5.0) (1.11.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\mypython\anaconda3\envs\py36\lib\site-packages (from jinja2->folium==0.5.0) (1.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\mypython\anaconda3\envs\py36\lib\site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\mypython\anaconda3\envs\py36\lib\site-packages (from requests->folium==0.5.0) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\mypython\anaconda3\envs\py36\lib\site-packages (from requests->folium==0.5.0) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in c:\mypython\anaconda3\envs\py36\lib\site-packages (from requests->folium==0.5.0) (2020.6.20)
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = '3S1PFTNL1HAFWEYMYHRLCVZVWN1DSK0IPHKSX5JXAGR3E1ML' # your Foursquare ID
CLIENT_SECRET = 'V4IEPFK4NJZZER4LJA33R2LX3S5KRBHVECAFZJDVTLFZUTBP' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 3S1PFTNL1HAFWEYMYHRLCVZVWN1DSK0IPHKSX5JXAGR3E1ML
# CLIENT_SECRET:V4IEPFK4NJZZER4LJA33R2LX3S5KRBHVECAFZJDVTLFZUTBP

# %%
address = 'Route de Vence, Saint-Jeannet, 06640'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.7463842 7.1539906

# %%
search_query = 'Les bacchanales'
radius = 10000
print(search_query + ' .... OK!')
# Out:
# Les bacchanales .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
print (results)

# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# {'meta': {'code': 200, 'requestId': '5fbb952adfad1e14df1b815e'}, 'response': {'venues': [{'id': '4bcc8e2eb6c49c7401ed9391', 'name': 'Les Bacchanales', 'location': {'address': '247 avenue de Provence', 'lat': 43.72687742112181, 'lng': 7.111660959953632, 'labeledLatLngs': [{'label': 'display', 'lat': 43.72687742112181, 'lng': 7.111660959953632}], 'distance': 4038, 'postalCode': '06140', 'cc': 'FR', 'city': 'Vence', 'state': "Provence-Alpes-Côte d'Azur", 'country': 'France', 'formattedAddress': ['247 avenue de Provence', '06140 Vence', 'France']}, 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1606128938', 'hasPerk': False}, {'id': '51ab974f498e5d77772dbada', 'name': 'Camping Les Cent Chênes', 'location': {'lat': 43.74587485528754, 'lng': 7.159169441765098, 'labeledLatLngs': [{'label': 'display', 'lat': 43.74587485528754, 'lng': 7.159169441765098}], 'distance': 420, 'cc': 'FR', 'country': 'France', 'formattedAddress': ['France']}, 'categories': [{'id': '4bf58dd8d48988d1e4941735', 'name': 'Campground', 'pluralName': 'Campgrounds', 'shortName': 'Campground', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/campground_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1606128938', 'hasPerk': False}, {'id': '57d46375498e4e908d1e6238', 'name': 'Les 13 Chimères', 'location': {'lat': 43.735821, 'lng': 7.187243, 'labeledLatLngs': [{'label': 'display', 'lat': 43.735821, 'lng': 7.187243}], 'distance': 2921, 'cc': 'FR', 'country': 'France', 'formattedAddress': ['France']}, 'categories': [{'id': '56aa371be4b08b9a8d5734e1', 'name': 'Vacation Rental', 'pluralName': 'Vacation Rentals', 'shortName': 'Vacation Rental', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1606128938', 'hasPerk': False}, {'id': '55e1b98a498ea9b7a4650a02', 'name': 'les gorges de la cagne', 'location': {'lat': 43.73509101649059, 'lng': 7.126681388286066, 'labeledLatLngs': [{'label': 'display', 'lat': 43.73509101649059, 'lng': 7.126681388286066}], 'distance': 2530, 'cc': 'FR', 'country': 'France', 'formattedAddress': ['France']}, 'categories': [{'id': '4eb1d4dd4b900d56c88a45fd', 'name': 'River', 'pluralName': 'Rivers', 'shortName': 'River', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/river_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1606128938', 'hasPerk': False}, {'id': '4e06032014959022c88d3ef2', 'name': 'Les Combes', 'location': {'lat': 43.7288573, 'lng': 7.1824835, 'labeledLatLngs': [{'label': 'display', 'lat': 43.7288573, 'lng': 7.1824835}], 'distance': 3009, 'postalCode': '06200', 'cc': 'FR', 'city': 'Nice', 'state': "Provence-Alpes-Côte d'Azur", 'country': 'France', 'formattedAddress': ['06200 Nice', 'France']}, 'categories': [], 'referralId': 'v-1606128938', 'hasPerk': False}, {'id': '518409aa498ef4b2105ca2a5', 'name': 'Les Vieux Fiancés', 'location': {'lat': 43.72265, 'lng': 7.111714, 'labeledLatLngs': [{'label': 'display', 'lat': 43.72265, 'lng': 7.111714}], 'distance': 4306, 'cc': 'FR', 'country': 'France', 'formattedAddress': ['France']}, 'categories': [{'id': '4bf58dd8d48988d116941735', 'name': 'Bar', 'pluralName': 'Bars', 'shortName': 'Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1606128938', 'hasPerk': False}, {'id': '4dd24d8fb0fb0becaf947bf7', 'name': 'Les Baous', 'location': {'lat': 43.722612, 'lng': 7.107769, 'labeledLatLngs': [{'label': 'display', 'lat': 43.722612, 'lng': 7.107769}], 'distance': 4563, 'cc': 'FR', 'city': 'Vence', 'state': "Provence-Alpes-Côte d'Azur", 'country': 'France', 'formattedAddress': ['Vence', 'France']}, 'categories': [{'id': '4bf58dd8d48988d1c4941735', 'name': 'Rest ...
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d1e4941735', 'name': 'C...    False
# 2  [{'id': '56aa371be4b08b9a8d5734e1', 'name': 'V...    False
# 3  [{'id': '4eb1d4dd4b900d56c88a45fd', 'name': 'R...    False
# 4                                                 []    False
#
#                          id        location.address location.cc location.city  \
# 0  4bcc8e2eb6c49c7401ed9391  247 avenue de Provence          FR         Vence
# 1  51ab974f498e5d77772dbada                     NaN          FR           NaN
# 2  57d46375498e4e908d1e6238                     NaN          FR           NaN
# 3  55e1b98a498ea9b7a4650a02                     NaN          FR           NaN
# 4  4e06032014959022c88d3ef2                     NaN          FR          Nice
#
#   location.country  location.distance  \
# 0           France               4038
# 1           France                420
# 2           France               2921
# 3           France               2530
# 4           France               3009
#
#                        location.formattedAddress  \
# 0  [247 avenue de Provence, 06140 Vence, France]
# 1                                       [France]
# 2                                       [France]
# 3                                       [France]
# 4                           [06200 Nice, France]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.72687742112181...     43.726877
# 1  [{'label': 'display', 'lat': 43.74587485528754...     43.745875
# 2  [{'label': 'display', 'lat': 43.735821, 'lng':...     43.735821
# 3  [{'label': 'display', 'lat': 43.73509101649059...     43.735091
# 4  [{'label': 'display', 'lat': 43.7288573, 'lng'...     43.728857
#
#    location.lng location.postalCode              location.state  \
# 0      7.111661               06140  Provence-Alpes-Côte d'Azur
# 1      7.159169                 NaN                         NaN
# 2      7.187243                 NaN                         NaN
# 3      7.126681                 NaN                         NaN
# 4      7.182484               06200  Provence-Alpes-Côte d'Azur
#
#                       name    referralId venuePage.id
# 0          Les Bacchanales  v-1606128938          NaN
# 1  Camping Les Cent Chênes  v-1606128938          NaN
# 2          Les 13 Chimères  v-1606128938          NaN
# 3   les gorges de la cagne  v-1606128938          NaN
# 4               Les Combes  v-1606128938          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                   name  \
# 0                      Les Bacchanales
# 1              Camping Les Cent Chênes
# 2                      Les 13 Chimères
# 3               les gorges de la cagne
# 4                           Les Combes
# 5                    Les Vieux Fiancés
# 6                            Les Baous
# 7                         Les Frangins
# 8                        Les Terrasses
# 9                 les cadrans solaires
# 10                       Les Luciolles
# 11              Les Jardins de Farnese
# 12                     Les Yeux Rouges
# 13                        Les Lavandes
# 14                   Les Vieux Fiancés
# 15         Les Créations de Corinandre
# 16                         Les Jardins
# 17                         les 4 coıns
# 18                          Les Selves
# 19        Les Délices De Saint-Antoine
# 20  Les jardins suspendus de st pierre
# 21                         Les Oranges
# 22                  Les Venus de Poche
# 23                    Les Chanterelles
# 24             Les Gourmandises Gelato
# 25              Les Haute Des Espinets
# 26           Les Vergers De Saint Paul
# 27                   Les Volets Blancs
# 28                        Les Colettes
# 29                         Les Bellets
#
#                                   categories                          address  \
# 0                          French Restaurant           247 avenue de Provence
# 1                                 Campground                              NaN
# 2                            Vacation Rental                              NaN
# 3                                      River                              NaN
# 4                                       None                              NaN
# 5                                        Bar                              NaN
# 6                                 Restaurant                              NaN
# 7                                 Restaurant            89 Route de Gattières
# 8   Residential Building (Apartment / Condo)                              NaN
# 9                                   Hospital                              NaN
# 10                                      None                              NaN
# 11                                  Building              Route de Cagnes 470
# 12                                 Gift Shop          134 avenue Emile Hugues
# 13                         French Restaurant                    Rue de Marché
# 14                                      Café                              NaN
# 15                                      None  136 Chemin de la Colle Germaine
# 16                           Other Nightlife                              NaN
# 17                                       Bar              Place Saint Isidore
# 18                         French Restaurant                              NaN
# 19                                    Bakery           341, Chemin Ginestière
# 20                                      None    34 Boulevard de la République
# 21                           Bed & Breakfast                              NaN
# 22                               Tailor Shop               42 Avenue de Féric
# 23                                      None   Route St Antoine de Ginestiere
# 24                            Ice Cream Shop                              NaN
# 25                                     Hotel                              NaN
# 26                                    Resort                              NaN
# 27                    Furniture / Home Store                5 rue des Bauques
# 28                                  Building                              NaN
# 29  Residential Building (Apartment / Condo)                              NaN
#
#     cc            city country  distance  \
# 0   FR           Vence  France      4038
# 1   FR             NaN  France       420
# 2   FR             NaN  France      2921
# 3   FR             NaN  France      2530
# 4   FR            Nice  France      3009
# 5   FR             NaN  France      4306
# 6   FR           Vence  France      4563
# 7   FR        La Gaude  France      3651
# 8   FR             NaN  France      3809
# 9   FR             NaN  France      4060
# 10  FR           Vence  France      4126
# 11  FR           Vence  France      4103
# 12  FR           Vence  France      4553
# 13  FR             NaN  France      4202
# 14  FR             NaN  France      4294
# 15  FR        Colomars  France      5360
# 16  FR             NaN  France      5354
# 17  FR            Nice  France      5219
# 18  FR             NaN  France      5212
# 19  FR            Nice  France      6468
# 20  FR          Carros  France      5840
# 21  FR             NaN  France      6175
# 22  FR            Nice  France      5948
# 23  FR            Nice  France      6385
# 24  FR             NaN  France      6025
# 25  FR             NaN  France      6474
# 26  FR      Saint-Paul  France      6244
# 27  FR      Saint-Paul  France      6039
# 28  FR  Cagnes-sur-Mer  France      7252
# 29  FR            Nice  France      7429
#
#                                      formattedAddress  \
# 0       [247 avenue de Provence, 06140 Vence, France]
# 1                                            [France]
# 2                                            [France]
# 3                                            [France]
# 4                                [06200 Nice, France]
# 5                                            [France]
# 6                                     [Vence, France]
# 7     [89 Route de Gattières, 06610 La Gaude, France]
# 8                                            [France]
# 9                                            [France]
# 10                                    [Vence, France]
# 11         [Route de Cagnes 470, 06140 Vence, France]
# 12     [134 avenue Emile Hugues, 06140 Vence, France]
# 13                            [Rue de Marché, France]
# 14                                           [France]
# 15  [136 Chemin de la Colle Germaine, 06670 Coloma...
# 16                                           [France]
# 17          [Place Saint Isidore, 06200 Nice, France]
# 18                                           [France]
# 19       [341, Chemin Ginestière, 06200 Nice, France]
# 20  [34 Boulevard de la République, 06510 Carros, ...
# 21                                           [France]
# 22           [42 Avenue de Féric, 06000 Nice, France]
# 23     [Route St Antoine de Ginestiere, Nice, France]
# 24                                           [France]
# 25                                           [France]
# 26                               [Saint-Paul, France]
# 27      [5 rue des Bauques, 06570 Saint-Paul, France]
# 28                           [Cagnes-sur-Mer, France]
# 29                               [06200 Nice, France]
#
#                                        labeledLatLngs        lat       lng  \
# 0   [{'label': 'display', 'lat': 43.72687742112181...  43.726877  7.111661
# 1   [{'label': 'display', 'lat': 43.74587485528754...  43.745875  7.159169
# 2   [{'label': 'display', 'lat': 43.735821, 'lng':...  43.735821  7.187243
# 3   [{'label': 'display', 'lat': 43.73509101649059...  43.735091  7.126681
# 4   [{'label': 'display', 'lat': 43.7288573, 'lng'...  43.728857  7.182484
# 5   [{'label': 'display', 'lat': 43.72265, 'lng': ...  43.722650  7.111714
# 6   [{'label': 'display', 'lat': 43.722612, 'lng':...  43.722612  7.107769
# 7   [{'label': 'display', 'lat': 43.7190494, 'lng'...  43.719049  7.179091
# 8   [{'label': 'display', 'lat': 43.767852, 'lng':...  43.767852  7.190893
# 9   [{'label': 'display', 'lat': 43.71831534555994...  43.718315  7.121745
# 10  [{'label': 'display', 'lat': 43.727942, 'lng':...  43.727942  7.109478
# 11  [{'label': 'display', 'lat': 43.71684193611145...  43.716842  7.123470
# 12  [{'label': 'display', 'lat': 43.722349, 'lng':...  43.722349  7.108181
# 13  [{'label': 'display', 'lat': 43.72267021875251...  43.722670  7.113329
# 14  [{'label': 'display', 'lat': 43.722777, 'lng':...  43.722777  7.111758
# 15  [{'label': 'display', 'lat': 43.7448847, 'lng'...  43.744885  7.220615
# 16  [{'label': 'display', 'lat': 43.703003, 'lng':...  43.703003  7.182747
# 17  [{'label': 'display', 'lat': 43.71102502296327...  43.711025  7.196599
# 18  [{'label': 'display', 'lat': 43.777921, 'lng':...  43.777921  7.201920
# 19  [{'label': 'display', 'lat': 43.70833383405301...  43.708334  7.214759
# 20  [{'label': 'display', 'lat': 43.78293085, 'lng...  43.782931  7.206115
# 21  [{'label': 'display', 'lat': 43.69942420630251...  43.699424  7.113113
# 22  [{'label': 'display', 'lat': 43.73928414, 'lng...  43.739284  7.227307
# 23  [{'label': 'display', 'lat': 43.70875989273432...  43.708760  7.213911
# 24  [{'label': 'display', 'lat': 43.6976, 'lng': 7...  43.697600  7.121530
# 25  [{'label': 'display', 'lat': 43.69037715760112...  43.690377  7.132307
# 26  [{'label': 'display', 'lat': 43.69971237637556...  43.699712  7.110927
# 27  [{'label': 'display', 'lat': 43.69742186862574...  43.697422  7.121666
# 28  [{'label': 'display', 'lat': 43.68124469849679...  43.681245  7.152595
# 29  [{'label': 'display', 'lat': 43.703243, 'lng':...  43.703243  7.224448
#
#    postalCode                       state                        id
# 0       06140  Provence-Alpes-Côte d'Azur  4bcc8e2eb6c49c7401ed9391
# 1         NaN                         NaN  51ab974f498e5d77772dbada
# 2         NaN                         NaN  57d46375498e4e908d1e6238
# 3         NaN                         NaN  55e1b98a498ea9b7a4650a02
# 4       06200  Provence-Alpes-Côte d'Azur  4e06032014959022c88d3ef2
# 5         NaN                         NaN  518409aa498ef4b2105ca2a5
# 6         NaN  Provence-Alpes-Côte d'Azur  4dd24d8fb0fb0becaf947bf7
# 7       06610  Provence-Alpes-Côte d'Azur  594d12e3851de51e2c0f4f21
# 8         NaN                         NaN  51b34bde498efda7ca222314
# 9         NaN                         NaN  50def410e4b07dd5d7645885
# 10        NaN                        PACA  4e5ead8b45dd21543f582a10
# 11      06140         Provence-Alpes-Côte  4c6c3b421fb2a14334e4fae6
# 12      06140  Provence-Alpes-Côte d'Azur  4d55151048ea6ea8b7e6d0a3
# 13        NaN                         NaN  4c587de3cc96c9b6f1647b2e
# 14        NaN                         NaN  4fd46d88e4b0a071e1a3519a
# 15      06670  Provence-Alpes-Côte d'Azur  589212f1a1492603cde2c00c
# 16        NaN                         NaN  50835007e4b0607ce962cd4d
# 17      06200                        PACA  51eade04498ee1f3df85cc10
# 18        NaN                         NaN  4c4eb3bcfb742d7f9788b52e
# 19      06200  Provence-Alpes-Côte d'Azur  4d554c3948ea6ea88e7cd3a3
# 20      06510  Provence-Alpes-Côte d'Azur  5ba8b423088158002c6bfc19
# 21        NaN                         NaN  517b90e2e4b0a2c66652c789
# 22      06000  Provence-Alpes-Côte d'Azur  5e49c73da179e30008b1a15a
# 23        NaN  Provence-Alpes-Côte d'Azur  4dc1169752b1877d85ab7ce5
# 24        NaN                         NaN  5b86c730121384002cb6a3bd
# 25        NaN                         NaN  4e267818483b329ccb3b6e47
# 26        NaN  Provence-Alpes-Côte d'Azur  4f89275ce4b0298189f6ee22
# 27      06570  Provence-Alpes-Côte d'Azur  4efdb5066da1cd0356c49da4
# 28        NaN  Provence-Alpes-Côte d'Azur  4e3aa5a7d164c429b72cdeb2
# 29      06200  Provence-Alpes-Côte d'Azur  577e45c0498ec0fb59421e2e

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around my address

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='My Address',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id = '4bcc8e2eb6c49c7401ed9391' # ID of Harry's Italian Pizza Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4bcc8e2eb6c49c7401ed9391?client_id=3S1PFTNL1HAFWEYMYHRLCVZVWN1DSK0IPHKSX5JXAGR3E1ML&client_secret=V4IEPFK4NJZZER4LJA33R2LX3S5KRBHVECAFZJDVTLFZUTBP&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4bcc8e2eb6c49c7401ed9391',
#  'name': 'Les Bacchanales',
#  'contact': {},
#  'location': {'address': '247 avenue de Provence',
#   'lat': 43.72687742112181,
#   'lng': 7.111660959953632,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 43.72687742112181,
#     'lng': 7.111660959953632}],
#   'postalCode': '06140',
#   'cc': 'FR',
#   'city': 'Vence',
#   'state': "Provence-Alpes-Côte d'Azur",
#   'country': 'France',
#   'formattedAddress': ['247 avenue de Provence', '06140 Vence', 'France']},
#  'canonicalUrl': 'https://foursquare.com/v/les-bacchanales/4bcc8e2eb6c49c7401ed9391',
#  'categories': [{'id': '4bf58dd8d48988d10c941735',
#    'name': 'French Restaurant',
#    'pluralName': 'French Restaurants',
#    'shortName': 'French',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 5},
#  'price': {'tier': 3, 'message': 'Expensive', 'currency': '€'},
#  'likes': {'count': 12,
#   'groups': [{'type': 'others', 'count': 12, 'items': []}],
#   'summary': '12 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 8.5,
#  'ratingColor': '73CF42',
#  'ratingSignals': 16,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 16,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 16,
#     'items': [{'id': '5b8a9071c9a517002c2d67e8',
#       'createdAt': 1535807601,
#       'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/2283263_td7PoH-lPyns3GxenWANAWgUu22hlfYvoeJUI60QqTM.jpg',
#       'width': 1920,
#       'height': 1440,
#       'user': {'isSanctioned': False,
#        'firstName': 'Peter',
#        'lastName': 'I',
#        'countryCode': 'US'},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1271696942,
#  'tips': {'count': 5,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 5,
#     'items': [{'id': '5a003a6a62420b35b8bb2a41',
#       'createdAt': 1509964394,
#       'text': 'Michelin star style restaurant, unusual but excellent meal. Wine selection was just perfect. Kind and caring service.',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/5a003a6a62420b35b8bb2a41',
#       'photo': {'id': '5a003a6b95d986639dab0ad0',
#        'createdAt': 1509964395,
#        'source': {'name': 'Foursquare for iOS',
#         'url': 'https://foursquare.com/download/#/iphone'},
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/11647739_Pr6ckxroKHitvfCPJTg1tx2HJaQXkWArZFCm8wo48_Y.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'photourl': 'https://fastly.4sqi.net/img/general/original/11647739_Pr6ckxroKHitvfCPJTg1tx2HJaQXkWArZFCm8wo48_Y.jpg',
#       'lang': 'en',
#       'likes': {'count': 0, 'groups': []},
#       'logView': True,
#       'agreeCount': 0,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'isSanctioned': False,
#        'firstName': 'Marc',
#        'countryCode': 'FR'},
#       'authorInteractionType': 'liked'}]}]},
#  'shortUrl': 'http://4sq.com/a7HH7c',
#  'timeZone': 'Europe/Paris',
#  'listed': {'count': 27,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 27,
#     'items': [{'id': '51375206e4b0488eb5f76205',
#       'name': 'I mie da provare',
#       'description': '',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'Angelo',
#        'countryCode': 'IT'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/angeloaccomando/list/i-mie-da-provare',
#       'canonicalUrl': 'https://foursquare.com/angeloaccomando/list/i-mie-da-provare',
#       'createdAt': 1362579974,
#       'updatedAt': 1605344899,
#       'photo': {'id': '50a6a5ace4b05f411fa873e6',
#        'createdAt': 1353098668,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/7261021_5LXsaStv-8r-wLkIzxx9IxPY-clwE_hHvjZr6RSi3o8.jpg',
#        'width': 720,
#        'height': 540,
#        'user': {'isSanctioned': False,
#         'firstName': 'Fabien',
#         'lastName': 'A',
#         'countryCode': 'CA'},
#        'visibility': 'public'},
#       'followers': {'count': 2},
#       'listItems': {'count': 139,
#        'items': [{'id': 'v4bcc8e2eb6c49c7401ed9391',
#          'createdAt': 1466357056}]}},
#      {'id': '53a333b2498e6824a1e0a79e',
#       'name': 'Saint-Paul-de-Vence',
#       'description': '',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'Sebastiaan',
#        'lastName': 'V',
#        'countryCode': 'BE'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/svcauwen/list/saintpauldevence',
#       'canonicalUrl': 'https://foursquare.com/svcauwen/list/saintpauldevence',
#       'createdAt': 1403204530,
#       'updatedAt': 1403205891,
#       'photo': {'id': '4e889e5c5c5cc919600a3c5e',
#        'createdAt': 1317576284,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/GUETGGDW1KVN0K53HA4SR5TKJFVRSKPYEDVYWMLJ5CB3D5AZ.jpg',
#        'width': 720,
#        'height': 537,
#        'user': {'isSanctioned': False,
#         'firstName': 'Serge',
#         'lastName': 'B',
#         'countryCode': 'US'},
#        'visibility': 'public'},
#       'followers': {'count': 2},
#       'listItems': {'count': 10,
#        'items': [{'id': 'v4bcc8e2eb6c49c7401ed9391',
#          'createdAt': 1403204917,
#          'photo': {'id': '511e2124e4b0e4dca780719b',
#           'createdAt': 1360929060,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/5726589_tVy-IsQKiAK3-eDof6BPYGEU1EMdL8GMVzIIV7zgrIQ.jpg',
#           'width': 720,
#           'height': 540,
#           'user': {'isSanctioned': False,
#            'firstName': 'Orsolya',
#            'lastName': 'C',
#            'countryCode': 'HU'},
#           'visibility': 'public'}}]}},
#      {'id': '51fcc07f498ea009727a5b90',
#       'name': "Côte d'Azur - Michelin - 1 star",
#       'description': '',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'Nikita',
#        'lastName': 'L',
#        'countryCode': 'RU'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/28585924/list/c%C3%B4te-dazur--michelin--1-star',
#       'canonicalUrl': 'https://foursquare.com/user/28585924/list/c%C3%B4te-dazur--michelin--1-star',
#       'createdAt': 1375518847,
#       'updatedAt': 1384291057,
#       'followers': {'count': 5},
#       'listItems': {'count': 25,
#        'items': [{'id': 'v4bcc8e2eb6c49c7401ed9391',
#          'createdAt': 1375519742}]}},
#      {'id': '572a2302cd10e474df5621fd',
#       'name': 'My nice Nice',
#       'description': '',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'Julia',
#        'lastName': 'R',
#        'countryCode': 'RU'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/28855862/list/my-nice-nice',
#       'canonicalUrl': 'https://foursquare.com/user/28855862/list/my-nice-nice',
#       'createdAt': 1462379266,
#       'updatedAt': 1500298214,
#       'followers': {'count': 2},
#       'listItems': {'count': 82,
#        'items': [{'id': 'v4bcc8e2eb6c49c7401ed9391',
#          'createdAt': 1492595096}]}}]}]},
#  'seasonalHours': [],
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '€€€',
#     'count': 1,
#     'items': [{'displayName': 'Price',
#       'displayValue': '€€€',
#       'priceTier': 3}]},
#    {'type': 'reservations',
#     'name': 'Reservations',
#     'summary': 'Reservations',
#     'count': 3,
#     'items': [{'displayName': 'Reservations', 'displayValue': 'Yes'}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 5,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'Yes'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}]}]},
#  'bestPhoto': {'id': '5b8a9071c9a517002c2d67e8',
#   'createdAt': 1535807601,
#   'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/2283263_td7PoH-lPyns3GxenWANAWgUu22hlfYvoeJUI60QqTM.jpg',
#   'width': 1920,
#   'height': 1440,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '5b8a9071c9a517002c2d67e8',
#    'value': -13092832},
#   'highlightTextColor': {'photoId': '5b8a9071c9a517002c2d67e8', 'value': -1},
#   'algoVersion': 3}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
    
    
result['response']['venue']['tips']['count']
# Out:
# 8.5
# 5

# %%
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fbb962faa0cc20f986d553c'},
#  'response': {'tips': {'count': 5,
#    'items': [{'id': '5a003a6a62420b35b8bb2a41',
#      'createdAt': 1509964394,
#      'text': 'Michelin star style restaurant, unusual but excellent meal. Wine selection was just perfect. Kind and caring service.',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/5a003a6a62420b35b8bb2a41',
#      'photo': {'id': '5a003a6b95d986639dab0ad0',
#       'createdAt': 1509964395,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/11647739_Pr6ckxroKHitvfCPJTg1tx2HJaQXkWArZFCm8wo48_Y.jpg',
#       'width': 1440,
#       'height': 1920,
#       'visibility': 'public'},
#      'photourl': 'https://fastly.4sqi.net/img/general/original/11647739_Pr6ckxroKHitvfCPJTg1tx2HJaQXkWArZFCm8wo48_Y.jpg',
#      'lang': 'en',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'agreeCount': 0,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'isSanctioned': False, 'firstName': 'Marc', 'countryCode': 'FR'},
#      'authorInteractionType': 'liked'}]}}}

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'photo', 'photourl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user', 'authorInteractionType'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered.reindex()
# Out:
# C:\mypython\Anaconda3\envs\py36\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                                                                                                     text  \
# 0  Michelin star style restaurant, unusual but excellent meal. Wine selection was just perfect. Kind and caring service.
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  0           0              5a003a6a62420b35b8bb2a41  Marc
#
#    user.lastName  user.id
# 0 NaN            NaN

# %%
idnumber = '48454224' # user ID with most agree counts and complete profile

url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&v={}'.format(idnumber, CLIENT_ID, CLIENT_SECRET, VERSION) # define URL

# send GET request
results = requests.get(url).json()
#user_data = results['response']['user']
user_data=results['response']['tips']['items'][0]['venue']['photos']['groups'][0]['items']#['items']
# display features associated with user
#user_data.keys()
#results
pd.set_option('display.max_colwidth', -1)

users_df = json_normalize(user_data)

# filter columns
filtered_columns = ['id','user.id','user.firstName','user.lastName']
tips_filtered = users_df.loc[:, filtered_columns]

# display user's tips
df=tips_filtered
df
#url
# Out:
#                          id  user.id user.firstName user.lastName
# 0  57099084498e6e5b94d5a312 NaN       Cesar          H
# 1  541e1d3b498e8e793290f7cd NaN       Cesar          H
# 2  53cb1c82498ef31f2f2eba34 NaN       Marcs          M

# %%
g=df.loc[df['user.id'] == '133773133']
print('First Name: ' + g['user.firstName'])
print('Last Name: ' + g['user.lastName'])

# 1. grab prefix of photo
# 2. grab suffix of photo
# 3. concatenate them using the image size  
Image(url='https://fastly.4sqi.net/img/general/540x920/133773133_ODR5Au05ENkSyu3xxfV3VOfCa0idDfm9Q4n8YbhZDRQ.jpg')
# Out:
# Series([], Name: user.firstName, dtype: object)
# Series([], Name: user.lastName, dtype: object)
# C:\mypython\Anaconda3\envs\py36\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# <img src="https://fastly.4sqi.net/img/general/540x920/133773133_ODR5Au05ENkSyu3xxfV3VOfCa0idDfm9Q4n8YbhZDRQ.jpg"/>

# %%
# define tips URL
user_id='484542633'
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

# send GET request and get user's tips
results = requests.get(url).json()
tips = results['response']['tips']['items']

# format column width
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips)

# filter columns
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display user's tips
tips_filtered
# Out:
#                                                                                                                                   text  \
# 0   They serve coffee!!!!!!
# 1   Quick, cheap lunch that tastes good! Way shorter line than Chipotle, too.
# 2   You’re not a real New Yorker until you’ve shame-ordered Insomnia Cookies for delivery at 3am
# 3   Good for you yet still tasty! Clean green protein is my go-to after I hit the gym 💪
# 4   Burger game strong 💪
# 5   Great burgers & fries! Also, this place is exactly what it’s like when you go to a bar in the Southwest. Source: I’m from Arizona.
# 6   Açaí bowl + peanut butter + whey protein = 💪💪💪
# 7   Highly underrated and way less crowded than Central Park!
# 8   Get the açaí bowl with peanut butter after your work out and thank me later 👌
# 9   When you want a burger, this should be the first thing that comes to mind. A+!
# 10  Way less crowded than Central Park! People who live in the neighborhood rave about Carl Schurz Park.
# 11  The best Mexican food in the Murray Hill / Kips Bay area!
# 12  Best coffee shop in the neighborhood!
# 13  When there’s nice weather, the rooftop at Tonic East is the best place to watch the game. Perfect for March Madness & NBA finals!
# 14  Rib game level 💯
#
#     agreeCount  disagreeCount                        id
# 0   1           0              5accc98c0313204c9d7ec157
# 1   2           0              5acbec70a0215b732e264fe8
# 2   1           0              5acbbd4eb1538e45373b07f5
# 3   2           0              5acbbcda01235808d5d6dc75
# 4   1           0              5ab575fb6bdee65f759da8c1
# 5   2           0              5ab5575d73fe2516ad8f363b
# 6   1           0              5ab42db53c858d64af2688a4
# 7   3           0              5ab42c396f706a29f53ad1a8
# 8   1           0              5ab42aca2a7ab6333652b266
# 9   1           0              5ab42a28da5e5617d18e3a6a
# 10  3           0              5ab429db1ffe971b060083f5
# 11  1           0              5ab3f53f8496ca57542d5549
# 12  1           0              5ab3f428da5e5617d17d1475
# 13  2           0              5ab3f3fedd70c572de886c9d
# 14  1           0              5ab3f372da2e00604ca53924
